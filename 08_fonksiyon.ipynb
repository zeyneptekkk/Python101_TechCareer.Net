# %%
def hesap_topla1():
    sayi1=10
    sayi2=39
    sayi3=sayi1+sayi2
    print("toplam: ",sayi3)
hesap_topla1()
# Out:
# toplam:  49

# %%
def hesap_topla2(s1,s2):
    s3=s1+s2
    print("toplam: ",s3)
hesap_topla2(2,3)
# Out:
# toplam:  5

# %%
def hesap_topla3(s1,s2=333):
    s3=s1+s2
    print("toplam: ",s3)
hesap_topla3(2,3) 
hesap_topla3(2)
# Out:
# toplam:  5
# toplam:  335

# %%
def hesap_topla4(s1,s2=333):
    s3=s1+s2
    return s3
hesap_topla4(2,3)
# Out:
# 5

# %%
def hesap_topla4(s1=9,s2=333):
    s3=s1+s2
    return s3
result=hesap_topla4(2)
print(result)
# Out:
# 335
