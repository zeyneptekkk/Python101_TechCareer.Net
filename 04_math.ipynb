# %%
import math
import random

# %%
print("PI:", math.pi)
# Out:
# PI: 3.141592653589793

# %%
print("E : ",math.e)
# Out:
# E :  2.718281828459045

# %%
print("karekök: ",math.sqrt(16))
# Out:
# karekök:  4.0

# %%
print("üslü:", math.pow(2,3))
# Out:
# üslü: 8.0

# %%
print("yukarı yuvarla: ",math.ceil(4.1))
print("aşağı yuvarla:  ",math.floor(4.1))
# Out:
# yukarı yuvarla:  5
# aşağı yuvarla:   4

# %%
print("log: ",math.log(100))
# Out:
# log:  4.605170185988092

# %%
num_list=[1,2,34,5]
print("toplam: ",sum(num_list))
# Out:
# toplam:  42

# %% [markdown]
# satısal işlemler rastgele

# %%
from random import randint,uniform


print("Rastgele Tam Sayı: ",randint(1,100))
print("Rastgele Ondalık sayı: ",uniform(0,1))
# Out:
# Rastgele Tam Sayı:  62
# Rastgele Ondalık sayı:  0.885828490484889
