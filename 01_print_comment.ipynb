# %%
#singele comment

"""
Multiple Comment
"""

# %%
print("Python Öğreniyorum canısı")
# Out:
# Python Öğreniyorum

# %%
print("Python","java","Nodejs")

#print("Python" "java" "Nodejs")   #yazamazsın yanlış kullanım
# Out:
# Python java Nodejs

# %%
print(122)
# Out:
# 122

# %%
print(12.1)
# Out:
# 12.1

# %%
print(12,1)
# Out:
# 12 1

# %%
#seperate yapısı

print("zeynep","tek","bilgisayarmüh",sep=" * ")
# Out:
# zeynep * tek * bilgisayarmüh

# %%
print("merhaba","yazılım", "dünyasına",end="***")
print("hoşgeldin")
# Out:
# merhaba yazılım dünyasına***hoşgeldin

# %%
#END yaspısı

print("merhaba","yazılım", "dünyasına","***" 
" hoşgeldin")
# Out:
# merhaba yazılım dünyasına *** hoşgeldin

# %%
#DOCSTRING YAPISI

print("""
merhaba ben zeynep tek 
python öğreniyorum
""")
# Out:
# merhaba ben zeynep tek
# python öğreniyorum

# %%
#ESCAPE YAPISI
#\n => new
#\t => tab

print("""
merhaba ben \tzeynep tek \npython öğreniyorum
""")
# Out:
# merhaba ben 	zeynep tek
# python öğreniyorum

# %%
#Değişken isimlendirme

name="Zeynep"
surname="Tek"
tc_number=123243

print("Adım: ", name, "\nSoyadım: ",surname)
print("Adım:%s Soyadım:%s "%(name,surname))      # %s => string , %d => decimal , %f => float
print(f"Adım: {name}  Soyadım: {surname}")
# Out:
# Adım:  Zeynep
# Soyadım:  Tek
# Adım:Zeynep Soyadım:Tek
# Adım: Zeynep  Soyadım: Tek
