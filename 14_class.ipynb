# %%
class Araba:
    
    marka="marka yazılmadı"
    model="model yazılmadı"
    yil=0
    renk="renk tanımlanmadı"
    
    #self: pythonda bir metod içinde o anki nesneye erişmek istiyorssak
    def calistir(self):
        print(f"Marka: {self.marka} \nModel: {self.yil} \nRenk: {self.renk} \nYıl: {self.yil}")

# %%
araba1=Araba()
araba1.calistir()
# Out:
# Marka: marka yazılmadı
# Model: 0
# Renk: renk tanımlanmadı
# Yıl: 0

# %%
araba2=Araba()
araba2.renk="kırmızı"
araba2.yil=2020
araba2.marka="bmw"
araba2.model="A3"
araba2.calistir()
# Out:
# Marka: bmw
# Model: 2020
# Renk: kırmızı
# Yıl: 2020
