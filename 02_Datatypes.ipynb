# %%
#Python dinamik türlü yüksek seviyeli interpreter bir dilldir
#Değişken türleri genel kurallar (common rules)
#değişken iismlendirmelerde: _
#snake_case

# %% [markdown]
# Numbers

# %%
number1=10
number2=-2
PI_NUMER=3.14159

print(f"number1: {number1} , number2: {number2} , PI_Number : {PI_NUMER}" )
# Out:
# number1: 10 , number2: -2 , PI_Number : 3.14159

# %% [markdown]
# String

# %%
str1="merhaba canısı"
str2="hello darling"

print(f"string1: {str1}")
# Out:
# string1: merhaba canısı

# %% [markdown]
# Boolean

# %%
is_login=True

print(f"giriş yapıldı mı : {is_login}")
# Out:
# giriş yapıldı mı : True

# %% [markdown]
# Variable

# %%
n1,n2,n3=1,2,3

# %% [markdown]
# Const

# %%
DATA_CONNECTION=255

# %% [markdown]
# List

# %%
my_list1=[1,2,3,4,5]
my_list2=[2,8,9,5,6,"siirt",True,12.3]

print(f"liste1: {my_list1} \nliste2: {my_list2}")
# Out:
# liste1: [1, 2, 3, 4, 5]
# liste2: [2, 8, 9, 5, 6, 'siirt', True, 12.3]

# %% [markdown]
# Tuple

# %%
#list yapısına çok benzer sadece immutable (değişmez) yapılarda kullanılkır

my_tuple=(1,2,3,"siirt")
print(f"my_tuple: {my_tuple}")
# Out:
# my_tuple: (1, 2, 3, 'siirt')

# %% [markdown]
# Dictionary

# %%
person={
    "name":"Zeynep",
    "surname":"Tek",
    "is_login": True,
    "number":123
}

print(person)
print(type(person))
# Out:
# {'name': 'Zeynep', 'surname': 'Tek', 'is_login': True, 'number': 123}
# <class 'dict'>
