# %%
number=[1,2,3,5,6]
for temp in number:
    print(temp)
# Out:
# 1
# 2
# 3
# 5
# 6

# %% [markdown]
# range

# %%
for temp in range(9):
    print(temp)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %% [markdown]
# while

# %%
i=0
while i<4:
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
