# %%
empty_dict={}

# %%
my_dict={
    "isim":"zeynep",
    "soyad":"Tek",
    "yas":23,
     "adres":{
         "il":"siirt",
         "ilçe":"kurtalan"
     }
}

# %%
print(my_dict)
# Out:
# {'isim': 'zeynep', 'soyad': 'Tek', 'yas': 23, 'adres': {'il': 'siirt', 'ilçe': 'kurtalan'}}

# %%
print(my_dict["isim"])
# Out:
# zeynep

# %%
print(my_dict.keys())
# Out:
# dict_keys(['isim', 'soyad', 'yas', 'adres'])

# %%
print(my_dict.items())
# Out:
# dict_items([('isim', 'zeynep'), ('soyad', 'Tek'), ('yas', 23), ('adres', {'il': 'siirt', 'ilçe': 'kurtalan'})])

# %%
print(my_dict.values())
# Out:
# dict_values(['zeynep', 'Tek', 23, {'il': 'siirt', 'ilçe': 'kurtalan'}])

# %%
for key,value in my_dict.items():
    print(f"{key}: {value}")
# Out:
# isim: zeynep
# soyad: Tek
# yas: 23
# adres: {'il': 'siirt', 'ilçe': 'kurtalan'}

# %%
my_dict.update({"meslek":"mühendis"})
print(my_dict)
# Out:
# {'isim': 'zeynep', 'soyad': 'Tek', 'yas': 23, 'adres': {'il': 'siirt', 'ilçe': 'kurtalan'}, 'meslek': 'mühendis'}
