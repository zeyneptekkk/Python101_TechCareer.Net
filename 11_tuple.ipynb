# %%
"""
Pythonda tuple ,birden fazla öğeyi sıralı bir sekilde saklayabilen
ancak değiştirilemez bir veri türüdür. tuplenin en büyük farkı oluşturulduktan sonra içeriğinin değiştirilemez olmasıdır

"""

# %%
empty_tuple=()

# %%
single_element_tuple=(5,)

# %%
multi_tuple=(1,2,4,5)

# %%
my_tuple=(10,20,30,40)
print(my_tuple[0])
print(my_tuple[-1])
# Out:
# 10
# 40

# %%
print(my_tuple[1:4])
# Out:
# (20, 30, 40)

# %%
print(my_tuple[0:3])
# Out:
# (10, 20, 30)

# %%
print(my_tuple[::2])
# Out:
# (10, 30)

# %%
for lang in my_tuple:
    print(lang)
# Out:
# 10
# 20
# 30
# 40

# %%
list=[1,2,4]
tuple=tuple(list)
print(tuple)
# Out:
# (1, 2, 4)
