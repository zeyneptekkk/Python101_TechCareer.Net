# %%
metin1="metin1"
print(metin1[0])
print(metin1[-1])
# Out:
# m
# 1

# %%
print(type(metin1))
# Out:
# <class 'str'>

# %%
print("kelime adeti: ", len(metin1))
# Out:
# kelime adeti:  6

# %%
print("kelime adeti: ",metin1*4,sep=" -")
# Out:
# kelime adeti: -metin1metin1metin1metin1

# %%
m1="zeynep"
m2="ayşe"
print(m1+m2)
# Out:
# zeynepayşe

# %% [markdown]
# Join

# %%
liste=["python","join"]
print(" ".join(liste))
# Out:
# python join

# %% [markdown]
# slicing

# %%
m4="python"
print(m4[1:4])
print(m4[0:2])
print(m4[1:4])
# Out:
# yth
# py
