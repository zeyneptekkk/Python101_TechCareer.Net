# %%
from datetime import datetime

current_time=datetime.now()
print(current_time)
# Out:
# 2026-02-20 17:20:51.342271

# %%
formatter_year_long=current_time.strftime("%Y-%m-%d")
print(formatter_year_long)
# Out:
# 2026-02-20
