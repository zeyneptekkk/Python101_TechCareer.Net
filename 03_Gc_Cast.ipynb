# %% [markdown]
# GC(Garbage Collection)

# %%
#pythonda değişkenlerin bellek yönetimi otomatik yapılır
#GC : gerksiz bellek tüketimini engeller

n1=22      #burdaki n1=22 artık çöptür
n1=33

# %% [markdown]
# None

# %%
#None: pythonda none özel bir veri türüdür. ve boş veya tanımsız bir değeri ifadde eder


data=None
print("Boş değer: ", data)
# Out:
# Boş değer:  None

# %% [markdown]
# Cast

# %%
#Cast : type casting yani değişkenlerin Tip dönüşümlerini kullanmak

n1="11"
print((int(n1)+19))
print(float(n1)+21)
# Out:
# 30
# 32.0

# %%
a=input("sayı gir")
if(a % 2 != 0){
    print(Tek)
}
