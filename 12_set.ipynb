# %%
#set ,sıralı olmayan eşsiz öğelerden oluşan ve değiştirilebilir bir veri yapısıdır

# %%
empty_set=set()

# %%
my_set1={1,2,3,4,3}
print(my_set1)
# Out:
# {1, 2, 3, 4}

# %%
my_set1.add(2)
print(my_set1)
# Out:
# {1, 2, 3, 4}

# %%
my_set1.pop()
print(my_set1)
# Out:
# {2, 3, 4}

# %% [markdown]
# union

# %%
set1={1,3,6}
set2={2,3,5}
print(set1.union(set2))
# Out:
# {1, 2, 3, 5, 6}

# %%
print(set1.intersection(set2))
# Out:
# {3}

# %%
print(set1.difference(set2))
# Out:
# {1, 6}

# %%
for item in my_set1:
    print(item)
# Out:
# 2
# 3
# 4
