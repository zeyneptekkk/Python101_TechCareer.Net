# %%
#homojen yapı
list_data=[1,10,2,3,4,5]

#heterojen yapı
list_data2=[1,3,"ali",2.2,True]

# %%
print(list_data[0])
# Out:
# 1

# %%
print(list_data.count(0))
# Out:
# 0

# %%
print(f"{list_data[len(list_data)-1]}")
# Out:
# 5

# %%
print(list_data2[1:4])
# Out:
# [3, 'ali', 2.2]

# %%
print(list_data2[:4])
# Out:
# [1, 3, 'ali', 2.2]

# %%
print(list_data2[::3])
# Out:
# [1, 2.2]

# %%
list_data.append(22)
print(list_data)
# Out:
# [1, 2, 3, 4, 5, 10, 22]

# %%
list_data.sort()
print(list_data)
# Out:
# [1, 2, 3, 4, 5, 10, 22]

# %%
squares=[x**2 for x in range(10)]
print(squares,end=" ")     #end ile yanyana yazmak
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
print(2 in list_data)
# Out:
# True

# %%
print(21 not in list_data)
# Out:
# True

# %%
list_data.reverse()
print(list_data)
# Out:
# [22, 10, 5, 4, 3, 2, 1]
